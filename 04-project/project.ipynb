# %%
import dataset as ds
import visualization as vis

# %%
candidates = ds.get_candidate_info_list(require_on_disk=False)
positive_info_list = [x for x in candidates if x[0]]
diameter_list = [x[1] for x in positive_info_list]

# %%
for i in range(0, len(diameter_list), 100):
    print('{:4} {:4.1f} mm'.format(i, diameter_list[i]))
# Out:
#    0 27.4 mm
#  100 18.8 mm
#  200 12.7 mm
#  300  8.6 mm
#  400  6.4 mm
#  500  5.4 mm
#  600  4.5 mm
#  700  0.0 mm
#  800  0.0 mm
#  900  0.0 mm
# 1000  0.0 mm
# 1100  0.0 mm
# 1200  0.0 mm
# 1300  0.0 mm

# %%
nodule_sample_list = vis.find_positive_samples()
# Out:
# 0 candidate_info_tuple(is_nodule=True, diameter_mm=10.4626083, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.128023902651233986592378348912', center_xyz=(34.1223242148, 87.8273440723, -100.189149775))
# 1 candidate_info_tuple(is_nodule=True, diameter_mm=6.800248866, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.129055977637338639741695800950', center_xyz=(-95.430332199, -87.6984598229, 1131.88013133))
# 2 candidate_info_tuple(is_nodule=True, diameter_mm=6.720277435, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354', center_xyz=(59.73, -157.0, -119.49))
# 3 candidate_info_tuple(is_nodule=True, diameter_mm=6.440878725, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492', center_xyz=(-100.46, 68.01, -230.55))
# 4 candidate_info_tuple(is_nodule=True, diameter_mm=6.378436317, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(146.12, -160.55, -309.93))
# ...

# %%
series_uid = nodule_sample_list[0].series_uid
vis.show_candidate(series_uid)
# Out:
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.128023902651233986592378348912 0 False [0]
